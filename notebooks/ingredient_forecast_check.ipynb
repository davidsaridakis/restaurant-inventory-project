# %%
import pandas as pd

df_check = pd.read_csv("../outputs/tables/weekly_procurement_plan_2026.csv")

# Check week 26
df_week_26 = df_check[df_check['week']==26]
df_week_26.head()
# Out:
#      year  week         ingredient unit  order_quantity
# 775  2026    26        bell_pepper   kg             6.0
# 776  2026    26  bulgar_wheat_fine   kg             7.0
# 777  2026    26             butter   kg             6.0
# 778  2026    26      cherry_tomato   kg            19.0
# 779  2026    26     chicken_fillet   kg            70.5
